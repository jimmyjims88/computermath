# %% [markdown]
# <a href="https://colab.research.google.com/github/jimmyjims88/computermath/blob/%EC%BD%94%EB%94%A9%EC%8B%A4%EC%8A%B5/12%EC%A3%BC%EC%B0%A8%20%EA%B8%B0%EC%88%A0%ED%86%B5%EA%B3%84%ED%95%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-30e5e5bb-a3c5-496c-861b-3e588a8a27cb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-30e5e5bb-a3c5-496c-861b-3e588a8a27cb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd #갭마인더 데이터셋 불러오기, 조작하기 코드 표현 실습URL링크

df = pd.read_csv('gapminder.tsv', sep = '\t')
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
# 행선택, 이름으로 접근

df.loc[1]
# Out:
# country      Afghanistan
# continent           Asia
# year                1957
# lifeExp           30.332
# pop              9240934
# gdpPercap      820.85303
# Name: 1, dtype: object

# %%
df.loc[[0, 10, 100, 1000]]
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 100    Bangladesh      Asia  1972   45.252  70759295   630.233627
# 1000     Mongolia      Asia  1972   53.754   1320500  1421.741975

# %%
# 행선택, 순서로 접근

df.iloc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.iloc[[0, 10, 100, 1000]]
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 100    Bangladesh      Asia  1972   45.252  70759295   630.233627
# 1000     Mongolia      Asia  1972   53.754   1320500  1421.741975

# %%
# 열선택

df['lifeExp']
# Out:
# 0       28.801
# 1       30.332
# 2       31.997
# 3       34.020
# 4       36.088
#          ...
# 1699    62.351
# 1700    60.377
# 1701    46.809
# 1702    39.989
# 1703    43.487
# Name: lifeExp, Length: 1704, dtype: float64

# %%
import pandas as pd #도수분포표 코드 표현 실습URL링크

df = pd.read_csv('gapminder.tsv', sep = '\t')
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
# 연도(year)를 기준으로 그룹화하고 인구(pop) 열의 도수분포표 생성
frequency_table = df.groupby('year')['pop'].sum().reset_index()

# 결과 출력
print(frequency_table)
# Out:
#     year         pop
# 0   1952  2406957150
# 1   1957  2664404580
# 2   1962  2899782974
# 3   1967  3217478384
# 4   1972  3576977158
# 5   1977  3930045807
# 6   1982  4289436840
# 7   1987  4691477418
# 8   1992  5110710260
# 9   1997  5515204472
# 10  2002  5886977579
# 11  2007  6251013179

# %%
import pandas as pd #히스토그램URL링크
import matplotlib
import matplotlib.pyplot as plt

df = pd.read_csv('gapminder.tsv', sep='\t')
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
plt.hist(df['lifeExp'], alpha = 0.3, bins=7, rwidth=1, color='red')
# Out:
# (array([ 12., 126., 313., 283., 275., 478., 217.]),
#  array([23.599     , 32.02814286, 40.45728571, 48.88642857, 57.31557143,
#         65.74471429, 74.17385714, 82.603     ]),
#  <BarContainer object of 7 artists>)

# %%
import pandas as pd     #원그래프URL링크
import matplotlib
import matplotlib.pyplot as plt

df = pd.read_csv("gapminder.tsv", sep="\t")
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
# 원그래프

df2 = df.groupby('continent')
df2.describe()
# Out:
#             year                                                               \
#            count    mean        std     min      25%     50%      75%     max
# continent
# Africa     624.0  1979.5  17.274110  1952.0  1965.75  1979.5  1993.25  2007.0
# Americas   300.0  1979.5  17.289102  1952.0  1965.75  1979.5  1993.25  2007.0
# Asia       396.0  1979.5  17.282097  1952.0  1965.75  1979.5  1993.25  2007.0
# Europe     360.0  1979.5  17.284285  1952.0  1965.75  1979.5  1993.25  2007.0
# Oceania     24.0  1979.5  17.631494  1952.0  1965.75  1979.5  1993.25  2007.0
#
#           lifeExp             ...          pop               gdpPercap  \
#             count       mean  ...          75%           max     count
# continent                     ...
# Africa      624.0  48.865330  ...  10801489.75  1.350312e+08     624.0
# Americas    300.0  64.658737  ...  18340309.00  3.011399e+08     300.0
# Asia        396.0  60.064903  ...  46300348.00  1.318683e+09     396.0
# ...

# %%
sizes = [624, 300, 396, 360, 24]
labels = [1, 2, 3, 4, 5]
colors = ['red', 'green', 'blue', 'yellow', 'purple']
plt.pie(sizes, labels = labels, colors = colors, autopct = '%.1f%%', shadow = False, startangle = 90 )
plt.axis('equal')
plt.show()

# %%
import pandas as pd     #상자 그림URL링크
import matplotlib
import seaborn as sns

df = pd.read_csv('gapminder.tsv', sep='\t')

sns.boxplot(x='continent', y='lifeExp', data=df)
# Out:
# <Axes: xlabel='continent', ylabel='lifeExp'>
